# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/daan/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['log']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
fig, ax = plt.subplots(figsize=(10, 8))
log = pd.read_csv('log.csv')['loss']
log_mean = log.rolling(window=100, center=False).mean()
# log.plot()
log_mean.plot()
